# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='/home/Downloads/deepak/deep-reinforcement-learning/p2-continuous-control/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# The simulation contains `20` identical agents, each with its own copy of the environment.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.09849999779835343

# %% [markdown]
# When finished, you can close the environment.

# %%
import gym
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
agent = Agent(state_size=state_size, action_size=action_size, random_seed=0)

# %%
def ddpg(n_episodes=20000, max_t=1000):
        
    scores_deque = deque(maxlen=100)
    scores = []
    for i_episode in range(1, n_episodes+1):
        avg_score = 0
        env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
        states = env_info.vector_observations                  # get the current state (for each agent)
        scores_collective = np.zeros(num_agents)               # initialize the score (for each agent)
        agent.t_step = 0
        agent.reset()
        score = 0
        for t in range(max_t):
            actions = agent.act(states)
            actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished            
            agent.step(states, actions, rewards, next_states, dones, t)
            states = next_states
            scores_collective += rewards
            if np.any(dones):
                break
        
        scores_deque.append(np.mean(scores_collective))
        avg_score = np.mean(scores_deque)
        scores.append(avg_score)
        
        print("\nEpisode {:}\t Average Score {:.2f}\tMin Score {:.2f}\tMax Score {:.2f}".format(i_episode, avg_score, scores_collective.min(), scores_collective.max()))
        print("Time {:.2f} s\n".format(time_taken))

        if np.mean(prev) > 30:
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')            
            break
    return scores

scores = ddpg()
# Out:
# Episode 1	 Average Score 0.44	Min Score 0.06	Max Score 1.13
# Time 18.90 s
#
#
# Episode 2	 Average Score 0.54	Min Score 0.19	Max Score 2.15
# Time 21.33 s
#
#
# Episode 3	 Average Score 0.54	Min Score 0.00	Max Score 1.46
# Time 21.84 s
#
#
# Episode 4	 Average Score 0.51	Min Score 0.00	Max Score 1.19
# Time 21.89 s
#
#
# Episode 5	 Average Score 0.53	Min Score 0.13	Max Score 1.26
# Time 20.68 s
#
#
# Episode 6	 Average Score 0.55	Min Score 0.08	Max Score 1.35
# Time 21.25 s
#
#
# Episode 7	 Average Score 0.62	Min Score 0.13	Max Score 2.49
# Time 23.05 s
#
#
# Episode 8	 Average Score 0.64	Min Score 0.10	Max Score 2.62
# Time 21.66 s
#
#
# Episode 9	 Average Score 0.61	Min Score 0.00	Max Score 0.87
# Time 24.85 s
#
#
# Episode 10	 Average Score 0.62	Min Score 0.00	Max Score 2.24
# Time 32.04 s
#
#
# Episode 11	 Average Score 0.65	Min Score 0.00	Max Score 2.40
# Time 35.71 s
#
#
# Episode 12	 Average Score 0.66	Min Score 0.00	Max Score 2.07
# Time 38.76 s
#
#
# Episode 13	 Average Score 0.68	Min Score 0.22	Max Score 1.83
# Time 36.53 s
#
#
# Episode 14	 Average Score 0.68	Min Score 0.33	Max Score 1.44
# Time 35.38 s
#
#
# Episode 15	 Average Score 0.69	Min Score 0.00	Max Score 2.08
# Time 37.34 s
#
#
# Episode 16	 Average Score 0.71	Min Score 0.07	Max Score 1.68
# Time 39.63 s
#
#
# Episode 17	 Average Score 0.72	Min Score 0.00	Max Score 2.10
# Time 37.60 s
#
#
# Episode 18	 Average Score 0.75	Min Score 0.22	Max Score 3.96
# Time 37.26 s
#
#
# Episode 19	 Average Score 0.79	Min Score 0.30	Max Score 2.55
# Time 39.23 s
#
#
# Episode 20	 Average Score 0.84	Min Score 0.14	Max Score 3.55
# Time 40.44 s
#
#
# Episode 21	 Average Score 0.88	Min Score 0.47	Max Score 3.39
# Time 39.26 s
#
#
# Episode 22	 Average Score 0.92	Min Score 0.70	Max Score 6.41
# Time 42.89 s
#
#
# Episode 23	 Average Score 0.96	Min Score 0.84	Max Score 3.93
# Time 41.79 s
#
#
# Episode 24	 Average Score 1.00	Min Score 0.00	Max Score 3.65
# Time 44.63 s
#
#
# Episode 25	 Average Score 1.03	Min Score 0.28	Max Score 3.09
# Time 43.68 s
#
#
# Episode 26	 Average Score 1.05	Min Score 0.49	Max Score 3.36
# Time 39.46 s
#
#
# Episode 27	 Average Score 1.07	Min Score 0.00	Max Score 4.01
# Time 41.92 s
#
#
# Episode 28	 Average Score 1.10	Min Score 0.30	Max Score 3.26
# Time 49.44 s
#
#
# Episode 29	 Average Score 1.12	Min Score 0.81	Max Score 3.37
# Time 41.71 s
#
#
# Episode 30	 Average Score 1.16	Min Score 0.56	Max Score 4.90
# Time 42.30 s
#
#
# Episode 31	 Average Score 1.19	Min Score 0.19	Max Score 6.50
# Time 41.48 s
#
#
# Episode 32	 Average Score 1.23	Min Score 0.28	Max Score 4.25
# Time 42.65 s
#
#
# Episode 33	 Average Score 1.27	Min Score 1.32	Max Score 4.00
# Time 52.57 s
#
#
# Episode 34	 Average Score 1.31	Min Score 0.99	Max Score 4.97
# Time 50.12 s
#
#
# Episode 35	 Average Score 1.35	Min Score 1.28	Max Score 4.65
# Time 45.88 s
#
#
# Episode 36	 Average Score 1.40	Min Score 1.53	Max Score 5.05
# Time 47.48 s
#
#
# Episode 37	 Average Score 1.45	Min Score 2.06	Max Score 5.06
# Time 44.93 s
#
#
# Episode 38	 Average Score 1.51	Min Score 1.83	Max Score 5.66
# Time 46.76 s
#
#
# Episode 39	 Average Score 1.55	Min Score 0.76	Max Score 6.42
# Time 57.90 s
#
#
# Episode 40	 Average Score 1.61	Min Score 1.65	Max Score 8.39
# Time 62.52 s
#
#
# Episode 41	 Average Score 1.65	Min Score 0.15	Max Score 5.72
# Time 67.85 s
#
#
# Episode 42	 Average Score 1.71	Min Score 1.79	Max Score 9.11
# Time 60.19 s
#
#
# Episode 43	 Average Score 1.76	Min Score 1.37	Max Score 6.36
# Time 59.63 s
#
#
# Episode 44	 Average Score 1.80	Min Score 1.85	Max Score 6.54
# Time 59.88 s
#
#
# Episode 45	 Average Score 1.85	Min Score 2.29	Max Score 6.55
# Time 66.04 s
#
#
# Episode 46	 Average Score 1.90	Min Score 2.64	Max Score 6.45
# Time 61.85 s
#
#
# Episode 47	 Average Score 1.96	Min Score 2.33	Max Score 10.25
# Time 66.45 s
#
#
# Episode 48	 Average Score 2.01	Min Score 1.55	Max Score 6.29
# Time 65.92 s
#
#
# Episode 49	 Average Score 2.06	Min Score 1.81	Max Score 5.64
# Time 65.87 s
#
#
# Episode 50	 Average Score 2.11	Min Score 2.64	Max Score 7.76
# Time 65.51 s
#
#
# Episode 51	 Average Score 2.18	Min Score 1.39	Max Score 9.83
# Time 67.35 s
#
#
# Episode 52	 Average Score 2.25	Min Score 1.20	Max Score 6.97
# Time 69.03 s
#
#
# Episode 53	 Average Score 2.31	Min Score 3.24	Max Score 9.59
# Time 59.13 s
#
#
# Episode 54	 Average Score 2.38	Min Score 3.08	Max Score 9.25
# Time 53.18 s
#
#
# Episode 55	 Average Score 2.44	Min Score 0.78	Max Score 7.23
# Time 49.06 s
#
#
# Episode 56	 Average Score 2.50	Min Score 2.87	Max Score 7.48
# Time 49.41 s
#
#
# Episode 57	 Average Score 2.53	Min Score 2.71	Max Score 9.97
# Time 48.98 s
#
#
# Episode 58	 Average Score 2.58	Min Score 3.08	Max Score 7.73
# Time 48.89 s
#
#
# Episode 59	 Average Score 2.61	Min Score 3.04	Max Score 12.06
# Time 48.99 s
#
#
# Episode 60	 Average Score 2.68	Min Score 0.72	Max Score 8.15
# Time 49.18 s
#
#
# Episode 61	 Average Score 2.71	Min Score 3.00	Max Score 8.64
# Time 48.75 s
#
#
# Episode 62	 Average Score 2.75	Min Score 2.06	Max Score 8.08
# Time 49.23 s
#
#
# Episode 63	 Average Score 2.82	Min Score 3.13	Max Score 8.80
# Time 49.17 s
#
#
# Episode 64	 Average Score 2.87	Min Score 3.87	Max Score 8.27
# Time 48.92 s
#
#
# Episode 65	 Average Score 2.93	Min Score 4.24	Max Score 9.68
# Time 49.04 s
#
#
# Episode 66	 Average Score 2.97	Min Score 2.85	Max Score 7.76
# Time 48.97 s
#
#
# Episode 67	 Average Score 3.02	Min Score 1.81	Max Score 8.62
# Time 49.10 s
#
#
# Episode 68	 Average Score 3.06	Min Score 3.25	Max Score 8.77
# Time 49.17 s
#
#
# Episode 69	 Average Score 3.12	Min Score 3.22	Max Score 10.55
# Time 49.49 s
#
#
# Episode 70	 Average Score 3.17	Min Score 3.17	Max Score 7.25
# Time 49.66 s
#
#
# Episode 71	 Average Score 3.21	Min Score 0.58	Max Score 8.34
# Time 48.51 s
#
#
# Episode 72	 Average Score 3.26	Min Score 3.09	Max Score 13.10
# Time 49.34 s
#
#
# Episode 73	 Average Score 3.31	Min Score 3.52	Max Score 11.37
# Time 48.92 s
#
#
# Episode 74	 Average Score 3.36	Min Score 3.30	Max Score 11.58
# Time 48.96 s
#
#
# Episode 75	 Average Score 3.41	Min Score 4.60	Max Score 10.71
# Time 48.10 s
#
#
# Episode 76	 Average Score 3.45	Min Score 4.12	Max Score 11.78
# Time 49.26 s
#
#
# Episode 77	 Average Score 3.49	Min Score 3.97	Max Score 13.02
# Time 50.00 s
#
#
# Episode 78	 Average Score 3.55	Min Score 4.60	Max Score 10.34
# Time 49.37 s
#
#
# Episode 79	 Average Score 3.59	Min Score 4.50	Max Score 13.06
# Time 52.02 s
#
#
# Episode 80	 Average Score 3.64	Min Score 2.29	Max Score 11.05
# Time 68.03 s
#
#
# Episode 81	 Average Score 3.67	Min Score 4.00	Max Score 11.58
# Time 76.33 s
#
#
# Episode 82	 Average Score 3.70	Min Score 2.54	Max Score 10.92
# Time 74.53 s
#
#
# Episode 83	 Average Score 3.75	Min Score 3.02	Max Score 10.77
# Time 78.00 s
#
#
# Episode 84	 Average Score 3.80	Min Score 4.00	Max Score 8.98
# Time 70.17 s
#
#
# Episode 85	 Average Score 3.84	Min Score 3.79	Max Score 11.97
# Time 70.56 s
#
#
# Episode 86	 Average Score 3.87	Min Score 3.92	Max Score 9.90
# Time 72.76 s
#
#
# Episode 87	 Average Score 3.92	Min Score 3.81	Max Score 10.32
# Time 86.70 s
#
#
# Episode 88	 Average Score 3.97	Min Score 2.86	Max Score 11.56
# Time 84.49 s
#
#
# Episode 89	 Average Score 4.02	Min Score 2.06	Max Score 14.19
# Time 83.33 s
#
#
# Episode 90	 Average Score 4.06	Min Score 4.68	Max Score 13.11
# Time 90.67 s
#
#
# Episode 91	 Average Score 4.13	Min Score 1.95	Max Score 10.72
# Time 96.37 s
#
#
# Episode 92	 Average Score 4.19	Min Score 1.11	Max Score 11.10
# Time 90.74 s
#
#
# Episode 93	 Average Score 4.25	Min Score 1.19	Max Score 11.24
# Time 70.37 s
#
#
# Episode 94	 Average Score 4.31	Min Score 3.52	Max Score 12.72
# Time 50.08 s
#
#
# Episode 95	 Average Score 4.39	Min Score 6.32	Max Score 23.03
# Time 50.50 s
#
#
# Episode 96	 Average Score 4.47	Min Score 3.64	Max Score 15.01
# Time 50.70 s
#
#
# Episode 97	 Average Score 4.54	Min Score 3.76	Max Score 14.59
# Time 54.48 s
#
#
# Episode 98	 Average Score 4.62	Min Score 3.16	Max Score 15.55
# Time 60.22 s
#
#
# Episode 99	 Average Score 4.68	Min Score 4.81	Max Score 22.97
# Time 79.90 s
#
#
# Episode 100	 Average Score 4.76	Min Score 6.96	Max Score 16.89
# Time 77.96 s
#
#
# Episode 101	 Average Score 4.82	Min Score 4.07	Max Score 17.22
# Time 77.11 s
#
#
# Episode 102	 Average Score 4.89	Min Score 6.34	Max Score 14.66
# Time 75.58 s
#
#
# Episode 103	 Average Score 4.97	Min Score 7.15	Max Score 16.03
# Time 71.14 s
#
#
# Episode 104	 Average Score 5.02	Min Score 7.28	Max Score 13.52
# Time 75.49 s
#
#
# Episode 105	 Average Score 5.08	Min Score 8.25	Max Score 32.45
# Time 75.06 s
#
#
# Episode 106	 Average Score 5.17	Min Score 7.58	Max Score 17.34
# Time 69.50 s
#
#
# Episode 107	 Average Score 5.26	Min Score 3.54	Max Score 15.02
# Time 65.13 s
#
#
# Episode 108	 Average Score 5.37	Min Score 6.89	Max Score 15.78
# Time 61.78 s
#
#
# Episode 109	 Average Score 5.47	Min Score 2.32	Max Score 16.86
# Time 65.16 s
#
#
# Episode 110	 Average Score 5.57	Min Score 6.03	Max Score 17.06
# Time 75.65 s
#
#
# Episode 111	 Average Score 5.68	Min Score 6.96	Max Score 16.43
# Time 74.85 s
#
#
# Episode 112	 Average Score 5.82	Min Score 8.23	Max Score 24.08
# Time 70.36 s
#
#
# Episode 113	 Average Score 5.93	Min Score 8.29	Max Score 18.59
# Time 69.92 s
#
#
# Episode 114	 Average Score 6.04	Min Score 1.14	Max Score 31.50
# Time 69.70 s
#
#
# Episode 115	 Average Score 6.17	Min Score 4.99	Max Score 31.21
# Time 67.85 s
#
#
# Episode 116	 Average Score 6.29	Min Score 1.44	Max Score 24.97
# Time 70.32 s
#
#
# Episode 117	 Average Score 6.41	Min Score 5.87	Max Score 20.89
# Time 68.89 s
#
#
# Episode 118	 Average Score 6.53	Min Score 2.59	Max Score 20.64
# Time 68.23 s
#
#
# Episode 119	 Average Score 6.67	Min Score 7.76	Max Score 29.04
# Time 71.93 s
#
#
# Episode 120	 Average Score 6.78	Min Score 2.60	Max Score 22.10
# Time 68.43 s
#
#
# Episode 121	 Average Score 6.91	Min Score 8.31	Max Score 21.49
# Time 75.17 s
#
#
# Episode 122	 Average Score 7.04	Min Score 10.08	Max Score 22.11
# Time 75.22 s
#
#
# Episode 123	 Average Score 7.15	Min Score 3.17	Max Score 19.93
# Time 73.59 s
#
#
# Episode 124	 Average Score 7.28	Min Score 6.87	Max Score 21.76
# Time 73.64 s
#
#
# Episode 125	 Average Score 7.43	Min Score 9.55	Max Score 29.36
# Time 72.70 s
#
#
# Episode 126	 Average Score 7.55	Min Score 6.32	Max Score 24.27
# Time 74.83 s
#
#
# Episode 127	 Average Score 7.68	Min Score 7.91	Max Score 19.91
# Time 75.09 s
#
#
# Episode 128	 Average Score 7.80	Min Score 8.98	Max Score 20.03
# Time 74.09 s
#
#
# Episode 129	 Average Score 7.93	Min Score 8.55	Max Score 24.07
# Time 73.44 s
#
#
# Episode 130	 Average Score 8.06	Min Score 9.61	Max Score 28.84
# Time 69.43 s
#
#
# Episode 131	 Average Score 8.18	Min Score 1.48	Max Score 21.36
# Time 70.98 s
#
#
# Episode 132	 Average Score 8.32	Min Score 10.43	Max Score 29.06
# Time 72.50 s
#
#
# Episode 133	 Average Score 8.47	Min Score 13.07	Max Score 22.04
# Time 75.36 s
#
#
# Episode 134	 Average Score 8.60	Min Score 11.36	Max Score 20.83
# Time 78.05 s
#
#
# Episode 135	 Average Score 8.74	Min Score 2.53	Max Score 28.57
# Time 74.90 s
#
#
# Episode 136	 Average Score 8.86	Min Score 7.80	Max Score 20.43
# Time 76.67 s
#
#
# Episode 137	 Average Score 8.98	Min Score 8.61	Max Score 20.27
# Time 77.68 s
#
#
# Episode 138	 Average Score 9.11	Min Score 9.33	Max Score 23.45
# Time 70.54 s
#
#
# Episode 139	 Average Score 9.25	Min Score 11.36	Max Score 27.77
# Time 68.50 s
#
#
# Episode 140	 Average Score 9.39	Min Score 9.64	Max Score 28.90
# Time 68.96 s
#
#
# Episode 141	 Average Score 9.50	Min Score 9.00	Max Score 19.34
# Time 70.49 s
#
#
# Episode 142	 Average Score 9.64	Min Score 10.76	Max Score 25.54
# Time 68.50 s
#
#
# Episode 143	 Average Score 9.77	Min Score 9.94	Max Score 23.29
# Time 73.08 s
#
#
# Episode 144	 Average Score 9.90	Min Score 7.53	Max Score 26.26
# Time 74.06 s
#
#
# Episode 145	 Average Score 10.04	Min Score 10.71	Max Score 31.19
# Time 69.24 s
#
#
# Episode 146	 Average Score 10.16	Min Score 8.55	Max Score 23.42
# Time 70.15 s
#
#
# Episode 147	 Average Score 10.29	Min Score 11.27	Max Score 24.63
# Time 69.60 s
#
#
# Episode 148	 Average Score 10.43	Min Score 10.58	Max Score 25.39
# Time 68.40 s
#
#
# Episode 149	 Average Score 10.59	Min Score 12.67	Max Score 27.43
# Time 68.33 s
#
#
# Episode 150	 Average Score 10.73	Min Score 9.06	Max Score 27.06
# Time 72.34 s
#
#
# Episode 151	 Average Score 10.88	Min Score 10.86	Max Score 30.55
# Time 70.25 s
#
#
# Episode 152	 Average Score 11.03	Min Score 13.26	Max Score 28.20
# Time 71.10 s
#
#
# Episode 153	 Average Score 11.17	Min Score 13.57	Max Score 29.43
# Time 74.65 s
#
#
# Episode 154	 Average Score 11.33	Min Score 16.45	Max Score 27.04
# Time 76.50 s
#
#
# Episode 155	 Average Score 11.49	Min Score 6.09	Max Score 27.86
# Time 75.91 s
#
#
# Episode 156	 Average Score 11.65	Min Score 14.09	Max Score 29.21
# Time 73.84 s
#
#
# Episode 157	 Average Score 11.81	Min Score 12.73	Max Score 29.01
# Time 68.12 s
#
#
# Episode 158	 Average Score 11.98	Min Score 13.19	Max Score 30.04
# Time 66.77 s
#
#
# Episode 159	 Average Score 12.15	Min Score 11.76	Max Score 31.43
# Time 68.80 s
#
#
# Episode 160	 Average Score 12.32	Min Score 13.47	Max Score 28.82
# Time 67.87 s
#
#
# Episode 161	 Average Score 12.52	Min Score 16.61	Max Score 29.59
# Time 70.47 s
#
#
# Episode 162	 Average Score 12.69	Min Score 14.21	Max Score 29.85
# Time 62.48 s
#
#
# Episode 163	 Average Score 12.87	Min Score 12.98	Max Score 29.74
# Time 69.89 s
#
#
# Episode 164	 Average Score 13.03	Min Score 14.88	Max Score 30.81
# Time 67.15 s
#
#
# Episode 165	 Average Score 13.20	Min Score 17.44	Max Score 30.46
# Time 66.80 s
#
#
# Episode 166	 Average Score 13.38	Min Score 13.00	Max Score 37.16
# Time 66.35 s
#
#
# Episode 167	 Average Score 13.55	Min Score 13.08	Max Score 33.22
# Time 68.60 s
#
#
# Episode 168	 Average Score 13.75	Min Score 15.02	Max Score 32.40
# Time 71.36 s
#
#
# Episode 169	 Average Score 13.92	Min Score 12.24	Max Score 31.21
# Time 70.98 s
#
#
# Episode 170	 Average Score 14.10	Min Score 13.09	Max Score 35.75
# Time 78.80 s
#
#
# Episode 171	 Average Score 14.29	Min Score 18.85	Max Score 32.97
# Time 78.41 s
#
#
# Episode 172	 Average Score 14.47	Min Score 13.07	Max Score 30.13
# Time 80.17 s
#
#
# Episode 173	 Average Score 14.65	Min Score 15.76	Max Score 32.98
# Time 76.30 s
#
#
# Episode 174	 Average Score 14.84	Min Score 16.51	Max Score 35.28
# Time 69.11 s
#
#
# Episode 175	 Average Score 15.00	Min Score 14.09	Max Score 30.79
# Time 68.75 s
#
#
# Episode 176	 Average Score 15.16	Min Score 12.15	Max Score 34.95
# Time 70.67 s
#
#
# Episode 177	 Average Score 15.33	Min Score 15.20	Max Score 34.04
# Time 71.50 s
#
#
# Episode 178	 Average Score 15.48	Min Score 12.94	Max Score 33.04
# Time 70.45 s
#
#
# Episode 179	 Average Score 15.65	Min Score 10.88	Max Score 30.41
# Time 68.83 s
#
#
# Episode 180	 Average Score 15.80	Min Score 11.66	Max Score 34.77
# Time 68.33 s
#
#
# Episode 181	 Average Score 15.97	Min Score 15.16	Max Score 36.75
# Time 68.23 s
#
#
# Episode 182	 Average Score 16.14	Min Score 15.56	Max Score 31.10
# Time 69.22 s
#
#
# Episode 183	 Average Score 16.35	Min Score 21.91	Max Score 33.57
# Time 69.62 s
#
#
# Episode 184	 Average Score 16.54	Min Score 18.93	Max Score 33.37
# Time 68.82 s
#
#
# Episode 185	 Average Score 16.74	Min Score 22.68	Max Score 34.32
# Time 66.42 s
#
#
# Episode 186	 Average Score 16.93	Min Score 14.06	Max Score 33.61
# Time 69.37 s
#
#
# Episode 187	 Average Score 17.11	Min Score 13.01	Max Score 32.79
# Time 67.40 s
#
#
# Episode 188	 Average Score 17.32	Min Score 16.68	Max Score 32.91
# Time 69.83 s
#
#
# Episode 189	 Average Score 17.53	Min Score 20.97	Max Score 35.33
# Time 65.81 s
#
#
# Episode 190	 Average Score 17.72	Min Score 14.84	Max Score 36.74
# Time 66.46 s
#
#
# Episode 191	 Average Score 17.94	Min Score 25.72	Max Score 32.73
# Time 66.41 s
#
#
# Episode 192	 Average Score 18.17	Min Score 17.50	Max Score 38.75
# Time 66.74 s
#
#
# Episode 193	 Average Score 18.36	Min Score 16.45	Max Score 34.70
# Time 67.45 s
#
#
# Episode 194	 Average Score 18.54	Min Score 10.22	Max Score 34.26
# Time 66.19 s
#
#
# Episode 195	 Average Score 18.73	Min Score 17.76	Max Score 37.30
# Time 67.52 s
#
#
# Episode 196	 Average Score 18.93	Min Score 19.47	Max Score 37.51
# Time 66.00 s
#
#
# Episode 197	 Average Score 19.10	Min Score 8.82	Max Score 34.08
# Time 66.92 s
#
#
# Episode 198	 Average Score 19.29	Min Score 20.59	Max Score 37.89
# Time 70.18 s
#
#
# Episode 199	 Average Score 19.45	Min Score 20.51	Max Score 36.88
# Time 71.01 s
#
#
# Episode 200	 Average Score 19.63	Min Score 18.65	Max Score 39.14
# Time 57.09 s
#
#
# Episode 201	 Average Score 19.83	Min Score 20.15	Max Score 34.92
# Time 56.00 s
#
#
# Episode 202	 Average Score 20.02	Min Score 20.46	Max Score 35.73
# Time 53.85 s
#
#
# Episode 203	 Average Score 20.19	Min Score 18.55	Max Score 34.30
# Time 56.76 s
#
#
# Episode 204	 Average Score 20.37	Min Score 15.40	Max Score 35.82
# Time 53.67 s
#
#
# Episode 205	 Average Score 20.54	Min Score 18.59	Max Score 37.27
# Time 54.56 s
#
#
# Episode 206	 Average Score 20.73	Min Score 21.74	Max Score 35.42
# Time 55.03 s
#
#
# Episode 207	 Average Score 20.92	Min Score 12.93	Max Score 38.19
# Time 54.01 s
#
#
# Episode 208	 Average Score 21.09	Min Score 15.54	Max Score 36.38
# Time 52.59 s
#
#
# Episode 209	 Average Score 21.27	Min Score 18.68	Max Score 36.60
# Time 52.60 s
#
#
# Episode 210	 Average Score 21.45	Min Score 21.04	Max Score 33.86
# Time 53.99 s
#
#
# Episode 211	 Average Score 21.60	Min Score 19.89	Max Score 32.90
# Time 49.44 s
#
#
# Episode 212	 Average Score 21.75	Min Score 21.80	Max Score 39.59
# Time 50.42 s
#
#
# Episode 213	 Average Score 21.91	Min Score 19.06	Max Score 34.99
# Time 48.85 s
#
#
# Episode 214	 Average Score 22.08	Min Score 22.25	Max Score 35.45
# Time 48.33 s
#
#
# Episode 215	 Average Score 22.21	Min Score 19.85	Max Score 31.69
# Time 48.71 s
#
#
# Episode 216	 Average Score 22.33	Min Score 11.65	Max Score 31.15
# Time 48.61 s
#
#
# Episode 217	 Average Score 22.47	Min Score 22.81	Max Score 33.28
# Time 49.49 s
#
#
# Episode 218	 Average Score 22.60	Min Score 21.38	Max Score 32.26
# Time 50.34 s
#
#
# Episode 219	 Average Score 22.72	Min Score 22.41	Max Score 31.36
# Time 52.69 s
#
#
# Episode 220	 Average Score 22.84	Min Score 19.52	Max Score 31.02
# Time 56.28 s
#
#
# Episode 221	 Average Score 22.95	Min Score 20.71	Max Score 31.58
# Time 53.82 s
#
#
# Episode 222	 Average Score 23.08	Min Score 19.31	Max Score 32.60
# Time 51.48 s
#
#
# Episode 223	 Average Score 23.20	Min Score 19.17	Max Score 29.56
# Time 53.37 s
#
#
# Episode 224	 Average Score 23.30	Min Score 18.49	Max Score 29.56
# Time 50.09 s
#
#
# Episode 225	 Average Score 23.39	Min Score 19.59	Max Score 29.80
# Time 49.41 s
#
#
# Episode 226	 Average Score 23.52	Min Score 22.91	Max Score 33.92
# Time 48.22 s
#
#
# Episode 227	 Average Score 23.66	Min Score 23.12	Max Score 32.40
# Time 51.61 s
#
#
# Episode 228	 Average Score 23.80	Min Score 24.16	Max Score 32.08
# Time 50.28 s
#
#
# Episode 229	 Average Score 23.91	Min Score 11.61	Max Score 34.73
# Time 50.05 s
#
#
# Episode 230	 Average Score 24.01	Min Score 19.28	Max Score 31.79
# Time 49.33 s
#
#
# Episode 231	 Average Score 24.10	Min Score 14.43	Max Score 33.59
# Time 49.24 s
#
#
# Episode 232	 Average Score 24.20	Min Score 17.95	Max Score 34.83
# Time 49.36 s
#
#
# Episode 233	 Average Score 24.29	Min Score 17.96	Max Score 35.87
# Time 49.66 s
#
#
# Episode 234	 Average Score 24.39	Min Score 17.02	Max Score 32.99
# Time 49.79 s
#
#
# Episode 235	 Average Score 24.48	Min Score 18.98	Max Score 35.05
# Time 49.79 s
#
#
# Episode 236	 Average Score 24.60	Min Score 16.96	Max Score 32.80
# Time 49.37 s
#
#
# Episode 237	 Average Score 24.71	Min Score 18.48	Max Score 32.84
# Time 48.56 s
#
#
# Episode 238	 Average Score 24.82	Min Score 24.34	Max Score 32.67
# Time 49.06 s
#
#
# Episode 239	 Average Score 24.94	Min Score 20.78	Max Score 35.10
# Time 48.77 s
#
#
# Episode 240	 Average Score 25.05	Min Score 11.61	Max Score 33.75
# Time 49.30 s
#
#
# Episode 241	 Average Score 25.19	Min Score 24.56	Max Score 32.48
# Time 48.95 s
#
#
# Episode 242	 Average Score 25.28	Min Score 21.06	Max Score 31.50
# Time 49.87 s
#
#
# Episode 243	 Average Score 25.38	Min Score 20.79	Max Score 31.87
# Time 48.83 s
#
#
# Episode 244	 Average Score 25.48	Min Score 19.51	Max Score 32.87
# Time 48.15 s
#
#
# Episode 245	 Average Score 25.59	Min Score 25.35	Max Score 32.91
# Time 49.42 s
#
#
# Episode 246	 Average Score 25.70	Min Score 23.22	Max Score 36.12
# Time 48.46 s
#
#
# Episode 247	 Average Score 25.80	Min Score 20.85	Max Score 32.67
# Time 49.35 s
#
#
# Episode 248	 Average Score 25.89	Min Score 23.03	Max Score 33.53
# Time 49.87 s
#
#
# Episode 249	 Average Score 25.96	Min Score 17.91	Max Score 31.51
# Time 48.83 s
#
#
# Episode 250	 Average Score 26.05	Min Score 18.10	Max Score 34.50
# Time 48.48 s
#
#
# Episode 251	 Average Score 26.13	Min Score 19.17	Max Score 33.49
# Time 48.86 s
#
#
# Episode 252	 Average Score 26.20	Min Score 17.92	Max Score 32.36
# Time 49.14 s
#
#
# Episode 253	 Average Score 26.28	Min Score 21.86	Max Score 34.34
# Time 48.52 s
#
#
# Episode 254	 Average Score 26.36	Min Score 20.64	Max Score 31.14
# Time 50.38 s
#
#
# Episode 255	 Average Score 26.45	Min Score 19.88	Max Score 38.60
# Time 49.22 s
#
#
# Episode 256	 Average Score 26.51	Min Score 18.71	Max Score 31.22
# Time 51.67 s
#
#
# Episode 257	 Average Score 26.60	Min Score 13.46	Max Score 33.57
# Time 48.98 s
#
#
# Episode 258	 Average Score 26.68	Min Score 19.63	Max Score 31.30
# Time 49.01 s
#
#
# Episode 259	 Average Score 26.74	Min Score 19.64	Max Score 31.52
# Time 48.09 s
#
#
# Episode 260	 Average Score 26.81	Min Score 16.35	Max Score 32.97
# Time 48.41 s
#
#
# Episode 261	 Average Score 26.90	Min Score 13.43	Max Score 34.03
# Time 52.08 s
#
#
# Episode 262	 Average Score 26.97	Min Score 17.76	Max Score 33.56
# Time 58.83 s
#
#
# Episode 263	 Average Score 27.04	Min Score 19.14	Max Score 35.55
# Time 48.39 s
#
#
# Episode 264	 Average Score 27.14	Min Score 17.43	Max Score 37.01
# Time 48.79 s
#
#
# Episode 265	 Average Score 27.21	Min Score 20.83	Max Score 33.06
# Time 48.46 s
#
#
# Episode 266	 Average Score 27.30	Min Score 3.06	Max Score 32.71
# Time 48.44 s
#
#
# Episode 267	 Average Score 27.37	Min Score 17.88	Max Score 33.01
# Time 49.26 s
#
#
# Episode 268	 Average Score 27.46	Min Score 17.79	Max Score 35.68
# Time 50.90 s
#
#
# Episode 269	 Average Score 27.56	Min Score 18.13	Max Score 36.82
# Time 54.79 s
#
#
# Episode 270	 Average Score 27.66	Min Score 16.68	Max Score 35.95
# Time 49.55 s
#
#
# Episode 271	 Average Score 27.72	Min Score 0.41	Max Score 31.90
# Time 49.39 s
#
#
# Episode 272	 Average Score 27.79	Min Score 14.78	Max Score 36.75
# Time 49.02 s
#
#
# Episode 273	 Average Score 27.87	Min Score 10.76	Max Score 32.74
# Time 52.39 s
#
#
# Episode 274	 Average Score 27.95	Min Score 23.55	Max Score 34.84
# Time 52.90 s
#
#
# Episode 275	 Average Score 28.02	Min Score 23.60	Max Score 38.91
# Time 51.50 s
#
#
# Episode 276	 Average Score 28.12	Min Score 19.57	Max Score 38.13
# Time 51.94 s
#
#
# Episode 277	 Average Score 28.21	Min Score 20.47	Max Score 32.41
# Time 54.66 s
#
#
# Episode 278	 Average Score 28.30	Min Score 22.61	Max Score 36.26
# Time 56.35 s
#
#
# Episode 279	 Average Score 28.39	Min Score 21.04	Max Score 33.68
# Time 53.39 s
#
#
# Episode 280	 Average Score 28.48	Min Score 21.28	Max Score 36.19
# Time 49.72 s
#
#
# Episode 281	 Average Score 28.56	Min Score 17.87	Max Score 37.11
# Time 50.12 s
#
#
# Episode 282	 Average Score 28.64	Min Score 17.39	Max Score 35.74
# Time 50.15 s
#
#
# Episode 283	 Average Score 28.73	Min Score 18.35	Max Score 36.31
# Time 51.41 s
#
#
# Episode 284	 Average Score 28.82	Min Score 15.24	Max Score 36.72
# Time 52.41 s
#
#
# Episode 285	 Average Score 28.91	Min Score 14.46	Max Score 38.16
# Time 50.39 s
#
#
# Episode 286	 Average Score 29.00	Min Score 18.64	Max Score 35.72
# Time 50.04 s
#
#
# Episode 287	 Average Score 29.10	Min Score 18.43	Max Score 39.64
# Time 52.28 s
#
#
# Episode 288	 Average Score 29.18	Min Score 20.18	Max Score 36.40
# Time 56.24 s
#
#
# Episode 289	 Average Score 29.26	Min Score 13.93	Max Score 37.47
# Time 49.49 s
#
#
# Episode 290	 Average Score 29.32	Min Score 16.56	Max Score 38.74
# Time 50.30 s
#
#
# Episode 291	 Average Score 29.40	Min Score 15.94	Max Score 36.51
# Time 50.06 s
#
#
# Episode 292	 Average Score 29.48	Min Score 14.26	Max Score 34.54
# Time 49.84 s
#
#
# Episode 293	 Average Score 29.57	Min Score 14.11	Max Score 37.43
# Time 49.87 s
#
#
# Episode 294	 Average Score 29.64	Min Score 14.42	Max Score 37.11
# Time 49.77 s
#
#
# Episode 295	 Average Score 29.74	Min Score 18.55	Max Score 38.50
# Time 50.11 s
#
#
# Episode 296	 Average Score 29.83	Min Score 14.56	Max Score 33.93
# Time 50.66 s
#
#
# Episode 297	 Average Score 29.89	Min Score 18.04	Max Score 39.82
# Time 53.43 s
#
#
# Episode 298	 Average Score 29.99	Min Score 17.97	Max Score 35.14
# Time 51.43 s
#
#
# Episode 299	 Average Score 30.09	Min Score 18.66	Max Score 37.42
# Time 49.52 s

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Average Score')
plt.xlabel('Episode #')

plt.show()
